# %%
import pandas as pd
import numpy as np

from tabulate import tabulate

import requests
import io
import json
from bs4 import BeautifulSoup

import duckdb

# %%
def show_table(table):
    print(tabulate(table, headers='keys', showindex=False, tablefmt='presto'))

# %%
location_base_url = 'https://ccclib.bibliocommons.com/v2/locations'

# %%
response = requests.get(location_base_url)

# %%
response.raise_for_status()

# %%
status_code = response.status_code
print(status_code)

if status_code == 200:
    location_html_content = response.text
else:
    print(response.text)
# Out:
# 200

# %%
print(location_html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" >
#   <head>
#     <!-- Data Layer -->
#     <script>
#       dataLayer = [{"bc.localBranch":null,"bc.product":"core","bc.gaCrossDomainEnabled":false,"bc.cmsEnabled":true,"bc.language":"en-US","bc.externalEventsGAId":null,"bc.libraryId":154,"bc.ga4MeasurementId":"G-ZET0BKEQP0","bc.version":"nerf17 Version 9.20.2@c0175bc Last updated 2024/02/08 12:56 Built 2024/02/08 16:06","bc.gaCrossDomainNames":[],"bc.externalCoreGAId":"UA-387101-12","bc.externalGaId":null,"bc.siteId":"CA-CONTRACOSTA","context":{},"bc.domain":"ccclib","bc.cmsUrl":"https://ccclib.org","bc.longName":"Contra Costa County Library","bc.allowGoogleAdFeatures":false,"bc.shortName":"CCCLib","bc.crazyEggId":"00178067"}];
#     </script>
#     <!-- end Data Layer -->
#     <!-- Start Google Tag Manager-->
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#             j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl
#             ;
#             f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-TDPBXX');</script>
#     <!-- End Google Tag Manager -->
#     <link rel="shortcut icon" href="/images/CA-CONTRACOSTA/favicon.ico" />
#     <link href="//cor-cdn-static.bibliocommons.com/assets/responsive_external_header-c60fcf3650be665b532bd462de3f54a7.css" media="all" rel="stylesheet" type="text/css" />
# <link href="//cor-liv-cdn-static.bibliocommons.com/dynamic_stylesheet/CA-CONTRACOSTA/external_library_branding.css?1707833757179" media="all" rel="stylesheet" type="text/css" />
# <link href="//cor-liv-cdn-static.bibliocommons.com/dynamic_stylesheet/CA-CONTRACOSTA/stylesheet.css?1707833757179" media="all" rel="stylesheet" type="text/css" />
#
#     <link data-chunk="main" rel="stylesheet" href="https://cdn-nerf.bibliocommons.com/app.main-7658bc69f3ad54d05cb2.css">
# <link data-chunk="EnhancedStyles" rel="stylesheet" href="https://cdn-nerf.bibliocommons.com/app.EnhancedStyles-ae051d93f6f43cdeff9b.css">
# <link data-chunk="app-components-locations-LocationsPage-LocationsPage" rel="stylesheet" href="https://cdn-nerf.bibliocommons.com/app.56-18dcd03437d701fca447.css">
# <link data-chunk="app-components-locations-LocationsPage-LocationsPage" rel="stylesheet" href="https://cdn-nerf.bibliocommons.com/app.app-components-locations-LocationsPage-LocationsPage-3b855117ad51f54c6d69.css">
#
#     <title data-react-helmet="true">Locations | Contra Costa County Library | BiblioCommons</title>
#     <meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" property="og:site_name" content="Contra Costa County Library"/><meta data-react-helmet="true" name="viewport" content="width=device-width, initial-scale=1.0"/><meta data-react-helmet="true" name="format-detection" content="telephone=no"/><meta data-react-helmet="true" name="App-Version" content="nerf17 Version 9.20.2@c0175bc Last updated 2024/02/08 12:56 Built 2024/02/08 16:06"/><meta data-react-helmet="true" name="description" content="Explore Contra Costa County Library. New titles, recently rated, and recently tagged by the library community."/><meta data-react-helmet="true" property="og:description" content="Explore Contra Costa County Library. New titles, recently rated, and recently tagged by the library community."/><meta data-react-helmet="true" property="twitter:description" content="Explore Contra Costa County Library. New titles, recently rated, and recently tagged by the library community."/><meta data-react-helmet="true" property="fb:app_id" content="821053187955346"/><meta data-react-helmet="true" property="og:type" content="website"/><meta data-react-helmet="true" property="title" content="Locations — Contra Costa County Library"/><meta data-react-helmet="true" property="og:title" content="Locations — Contra Costa County Library"/><meta data-react-helmet="true" property="twitter:title" content="Locations — Contra Costa County Library"/><meta data-react-helmet="true" property="twitter:card" content="summary"/><meta data-react-helmet="true" property="twitter:creator" content="@contracostalib"/><meta data-react-helmet="true" property="twitter:site" content="@contracostalib"/>
#     <script data-react-helmet="true" type="application/ld+json">{"@context":"http://schema.org","@type":"Library","name":"Contra Costa County Library","url":"https://ccclib.bibliocommons.com","logo":"https://ccclib.bibliocommons.com/images/CA-CONTRACOSTA/logo.png","image":"https://ccclib.bibliocommons.com/images/CA-CONTRACOSTA/logo.png"}</script>
#
#     <link data-chunk="app-components-locations-LocationsPage-LocationsPage" rel="preload" as="style" href="https://cdn-nerf.bibliocommons.com/app.app-components-locations-LocationsPage-LocationsPage-3b855117ad51f54c6d69.css">
# <link data-chunk="app-components-locations-LocationsPage-LocationsPage" rel="preload" as="style" href="https://cdn-nerf.bibliocommons.com/app.56-18dcd03437d701fca447.css">
# <link data-chunk="EnhancedStyles" rel="preload" as="style" href="https://cdn-nerf.bibliocommons.com/app.EnhancedStyles-ae051d93f6f43cdeff9b.css">
# <link data-chunk="main" rel="preload" as="style" href="https://cdn-nerf.bibliocommons.com/app.main-7658bc69f3ad54d05cb2.css">
# <link data-chunk="main" rel="preload" as="script" href="https://cdn-nerf.bibliocommons.com/app.main-7658bc69f3ad54d05cb2.js">
# <link data-chunk="EnhancedStyles" rel="preload" as="script" href="https://cdn-nerf.bibliocommons.com/app.EnhancedStyles-ae051d93f6f43cdeff9b.js">
# <link data-chunk="app-components-locations-LocationsPage-LocationsPage" rel="preload" as="script" href="https://cdn-nerf.bibliocommons.com/app.56-18dcd03437d701fca447.js">
# <link data-chunk="app-components-locations-LocationsPage-LocationsPage" rel="preload" as="script" href="https://cdn-nerf.bibliocommons.com/app.app-components-locations-LocationsPage-LocationsPage-3b855117ad51f54c6d69.js">
#   </head>
#   <body>
#     <div data-iso-key="_0"><div id="react-root"><div><div class="cp-screen-reader-shortcuts"><div><span class="bc_core_external">
#   <a class="hidden-xs hidden-sm screen_reader_nav" href="#header_main_nav" data-js="skip_to_main_nav">
#     Skip to main navigation
#   </a>
#   <a class="hidden-lg hidden-md screen_reader_nav" href="#header_main_nav" data-js="header_nav_xs_trigger" data-target = "header-main-nav">
#     Skip to main navigation
#   </a>
#     <a class="hidden-xs hidden-sm screen_reader_nav" href="#desktop_search_form" data-js="skip_to_search_field">
#       Skip to search
#     </a>
#   <a class="hidden-lg hidden-md screen_reader_nav" href="#mobile_search_form" data-js="header_search_xs_trigger">
#     Skip to search
#   </a>
# </span></div><a href="#content" class="screen_reader_nav">Skip to Content</a></div><div class="cp-core-external-header"><div data-testid="headerWrapper"><header>
#
#   <script type="text/javascript">
#   window.BCHeaderConfig = {"is_externally_rendered":true,"initial_state":null,"core_base_url":"https://ccclib.bibliocommons.com/","web_base_url":"https://ccclib.org/","domain":"ccclib","messages":{"ada_suggestions_below":"Suggestions below."},"analytics":{"auto_suggest_category":"v2-search-autosuggest","auto_suggest_click_event":"bc.searchAutoSuggestClick","link_click_action":"v2-link-click"}};
# </script>
#
#
#     <!-- START EXTERNAL HEADER -->
#     <div class="bc_core_external">
#   <div class="cp_header_wrapper">
#     <div class="cp_header" data-js="cp_header" testid="header" data-responsive="true">
#
#       <div class="cp_header_biblio_bar">
#   <div class="container">
#     <div class="row">
#
#       <div class="col-xs-12">
#           <div class="pull-left">
#             <div class="hidden-xs">
#   <a href="javascript:void(0);" aria-expanded="false" class="biblio_bar_link language_dropdown_trigger dropdown-toggle hide_trigger_icon" data-toggle="dropdown" id="biblio_language_trigger" lang="en-US" testid="selected_language">
#     <svg aria-hidden="true" class="svg_icon " focusable="false" height="12" viewBox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg">
#   <path d="M5.994 0C2.682 0 0 2.688 0 6C0 9.312 2.682 12 5.994 12C9.312 12 12 9.312 12 6C12 2.688 9.312 0 5.994 0ZM10.152 3.6H8.382C8.19 2.85 7.914 2.13 7.554 1.464C8.658 1.842 9.576 2.61 10.152 3.6ZM6 1.224C6.498 1.944 6.888 2.742 7.146 3.6H4.854C5.112 2.742 5.502 1.944 6 1.224ZM1.356 7.2C1.26 6.816 1.2 6.414 1.2 6C1.2 5.586 1.26 5.184 1.356 4.8H3.384C3.336 5.196 3.3 5.592 3.3 6C3.3 6.408 3.336 6.804 3.384 7.2H1.356ZM1.848 8.4H3.618C3.81 9.15 4.086 9.87 4.446 10.536C3.342 10.158 2.424 9.396 1.848 8.4ZM3.618 3.6H1.848C2.424 2.604 3.342 1.842 4.446 1.464C4.086 2.13 3.81 2.85 3.618 3.6ZM6 10.776C5.502 10.056 5.112 9.258 4.854 8.4H7.146C6.888 9.258 6.498 10.056 6 10.776ZM7.404 7.2H4.596C4.542 6.804 4.5 6.408 4.5 6C4.5 5.592 4.542 5.19 4.596 4.8H7.404C7.458 5.19 7.5 5.592 7.5 6C7.5 6.408 7.458 6.804 7.404 7.2ZM7.554 10.536C7.914 9.87 8.19 9.15 8.382 8.4H10.152C9.576 9.39 8.658 10.158 7.554 10.536ZM8.616 7.2C8.664 6.804 8.7 6.408 8.7 6C8.7 5.592 8.664 5.196 8.616 4.8H10.644C10.74 5.184 10.8 5.586 10.8 6C10.8 6.414 10.74 6.816 10.644 7.2H8.616Z" />
# </svg>
# <span aria-hidden="true">English</span><span class="sr-only" data-js="sr-only-dropdown-toggle" data-text-collapsed="English, collapsed" data-text-expanded="English, expanded">English, collapsed</span><span aria-hidden="true" class="icon-arrow"></span></a>  <ul class="dropdown-menu biblio_languages"
#       aria-labelledby="biblio_language_trigger"
#       testid="list_of_langs">
#       <li><a href="/info/switch_language?external=true&amp;selected_language=es-ES" class="" lang="es-ES">Español</a></li>
#       <li><a href="/info/switch_language?external=true&amp;selected_language=zh-CN" class="" lang="zh-CN">简体中文</a></li>
#       <li><a href="/info/switch_language?external=true&amp;selected_language=vi-VN" class="" lang="vi-VN">Tiếng Việt</a></li>
#       <li><a href="/info/switch_language?external=true&amp;selected_language=ru-RU" class="" lang="ru-RU">Русский</a></li>
#   </ul>
# </div>
#
# <a href="#language-switcher-overlay"
#    class="biblio_bar_link visible-xs language_overlay_trigger"
#    data-js="language_overlay_trigger"
#    data-target="language_switcher_overlay"
#    testid="language_trigger">
#   <svg aria-hidden="true" class="svg_icon " focusable="false" height="12" viewBox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg">
#   <path d="M5.994 0C2.682 0 0 2.688 0 6C0 9.312 2.682 12 5.994 12C9.312 12 12 9.312 12 6C12 2.688 9.312 0 5.994 0ZM10.152 3.6H8.382C8.19 2.85 7.914 2.13 7.554 1.464C8.658 1.842 9.576 2.61 10.152 3.6ZM6 1.224C6.498 1.944 6.888 2.742 7.146 3.6H4.854C5.112 2.742 5.502 1.944 6 1.224ZM1.356 7.2C1.26 6.816 1.2 6.414 1.2 6C1.2 5.586 1.26 5.184 1.356 4.8H3.384C3.336 5.196 3.3 5.592 3.3 6C3.3 6.408 3.336 6.804 3.384 7.2H1.356ZM1.848 8.4H3.618C3.81 9.15 4.086 9.87 4.446 10.536C3.342 10.158 2.424 9.396 1.848 8.4ZM3.618 3.6H1.848C2.424 2.604 3.342 1.842 4.446 1.464C4.086 2.13 3.81 2.85 3.618 3.6ZM6 10.776C5.502 10.056 5.112 9.258 4.854 8.4H7.146C6.888 9.258 6.498 10.056 6 10.776ZM7.404 7.2H4.596C4.542 6.804 4.5 6.408 4.5 6C4.5 5.592 4.542 5.19 4.596 4.8H7.404C7.458 5.19 7.5 5.592 7.5 6C7.5 6.408 7.458 6.804 7.404 7.2ZM7.554 10.536C7.914 9.87 8.19 9.15 8.382 8.4H10.152C9.576 9.39 8.658 10.158 7.554 10.536ZM8.616 7.2C8.664 6.804 8.7 6.408 8.7 6C8.7 5.592 8.664 5.196 8.616 4.8H10.644C10.74 5.184 10.8 5.586 10.8 6C10.8 6.414 10.74 6.816 10.644 7.2H8.616Z" />
# </svg>
#   <span class="sr-only">
#     Select language, opens an overlay
#   </span>
# </a>
#
# <script type="text/html" data-js="language_switcher_overlay">
#   <div class="language_switcher_overlay">
#     <h3>Select language</h3>
#     <ul>
#         <li><a href="/info/switch_language?external=true&amp;selected_language=es-ES" class="" lang="es-ES">Español</a></li>
#         <li><a href="/info/switch_language?external=true&amp;selected_language=zh-CN" class="" lang="zh-CN">简体中文</a></li>
#         <li><a href="/info/switch_language?external=true&amp;selected_language=vi-VN" class="" lang="vi-VN">Tiếng Việt</a></li>
#         <li><a href="/info/switch_language?external=true&amp;selected_language=ru-RU" class="" lang="ru-RU">Русский</a></li>
#     </ul>
#   </div>
# </script>
#
#           </div>
#
#         <div class="pull-left visible-xs help_location_links_xs">
#             <a href="https://ccclib.bibliocommons.com/locations"
#    class="biblio_bar_link header_hours_and_locations_link"
#    data-js="header_hours_and_locations_link"
#    data-target="header_locations_dropdown_menu"
#    data-ga-category="header_locations_link"
#    data-ga-label="Locations Link"
#    testid="link_hours_and_locations">
#   <i aria-hidden="true" class=" icon-location"></i>
#   <span class="sr-only-xs">Hours & Location</span>
# </a>
#
#           <a href="https://ccclib.org/using-the-library"
#    class="biblio_bar_link header_help_link"
#    data-js="header_help_link"
#    data-target="header_help_dropdown_menu"
#    data-ga-category="header_help_link"
#    data-ga-label="Help Link"
#    testid="link_help">
#   <i aria-hidden="true" class=" icon-help-circled"></i>
#   <span class="hidden-xs" aria-hidden="true">Help</span>
#   <span class="sr-only">Help, opens a new window</span>
# </a>
#
#         </div>
#
#         <div class="pull-right header_biblio_bar_right" >
#           <div class="hidden-xs help_location_links" >
#               <div class="header_locations_dropdown_wrapper hidden-xs"
#      data-ga-category="header_locations_dropdown"
#      data-ga-label="Locations Dropdown"
#      data-ga-event="show"
#      testid="header_locations_dropdown">
#   <a href="#" aria-expanded="false" aria-haspopup="true" class="biblio_bar_link dropdown-toggle hide_trigger_icon" data-toggle="dropdown" id="header_locations_dropdown_trigger" role="button" testid="header_locations_dropdown_trigger">
#       <i aria-hidden="true" class=" icon-location"></i>
# <span aria-hidden="true">Hours & Locations</span><span class="sr-only" data-js="sr-only-dropdown-toggle" data-text-collapsed="Hours & Locations, collapsed" data-text-expanded="Hours & Locations, expanded">Hours & Locations, collapsed</span><span aria-hidden="true" class="icon-arrow"></span></a>
#   <div class="dropdown-menu" data-js="header_locations_dropdown_menu" aria-labelledby="header_locations_dropdown_trigger">
#     <div class="header_locations_menu">
#       <div class="form-group">
#         <form action="https://ccclib.bibliocommons.com/locations" autocomplete="off" method="get">
#           <label for="locations_search_input">Find by address or ZIP code</label>
#           <div class="input-group">
#             <input autocomplete="off" class="form-control text" id="locations_search_input" name="near_addr" testid="locations_search_input" type="text" />
#             <span class="input-group-btn">
#               <button type="submit" class="btn btn-primary btn-flat">
#                 <i aria-hidden="true" class=" icon-search"></i>
#                 <span class="sr-only">Search</span>
#               </button>
#             </span>
#           </div>
# </form>      </div>
#
#       <div class="form-group locations_geo_search" data-js="locations_geo_search">
#         <button class="btn btn-block btn-default btn-flat locations_geo_search_btn" data-js="locations_geo_search_button">
#           <i aria-hidden="true" class=" icon-spinner animate-spin"></i>
#           <i aria-hidden="true" class=" icon-crosshair"></i>
#           Use current location
#         </button>
#       </div>
#
#         <!-- Template: t_biblionav_preferred_locations -->
#         <div data-js='biblionav_preferred_locations'></div>
#
#         <script id="t_biblionav_preferred_locations" type="x-handlebars-template">
#           <div class="form-group preferred_locations">
#             <label>Preferred Locations</label>
#             <a href="https://ccclib.bibliocommons.com/account/pickup_location" class="preferred_locations_edit_link" data-ga-category="header_preferred_locations_edit" data-ga-label="Preferred Locations Edit Link" testid="header_preferred_locations_edit">Edit</a>
#
#             <ol>
#               {{#each preferred_locations}}
#                 <li><a data-ga-category="header_preferred_locations_branch_name" href="{{url}}">{{name}}</a></li>
#               {{/each}}
#             </ol>
#
#             {{#if can_add_locations}}
#               <a href="https://ccclib.bibliocommons.com/account/pickup_location" class="preferred_locations_edit_link" data-ga-category="header_preferred_locations_add" data-ga-label="Preferred Locations Add Link" testid="header_preferred_locations_add">Add Location</a>
#             {{/if}}
#           </div>
#         </script>
#
#       <div class="form-group">
#         <a href="https://ccclib.bibliocommons.com/locations" testid="header_locations_see_all">See all locations</a>
#       </div>
#
#     </div>
#   </div>
# </div>
#
#
#               <div class="header_help_dropdown_wrapper hidden-xs"
#      data-ga-category="header_help_dropdown"
#      data-ga-label="Help Dropdown"
#      data-ga-event="show"
#      testid="header_help_dropdown">
#   <a href="#" aria-expanded="false" aria-haspopup="true" class="biblio_bar_link dropdown-toggle hide_trigger_icon" data-toggle="dropdown" id="header_help_dropdown_trigger" role="button" testid="header_help_dropdown_trigger">
#       <i aria-hidden="true" class=" icon-help-circled"></i>
# <span aria-hidden="true">Help</span><span class="sr-only" data-js="sr-only-dropdown-toggle" data-text-collapsed="Help, collapsed" data-text-expanded="Help, expanded">Help, collapsed</span><span aria-hidden="true" class="icon-arrow"></span></a>
#   <div class="dropdown-menu" data-js="header_help_dropdown_menu" aria-labelledby="header_help_dropdown_trigger">
#     <div class="header_help_menu">
#       <div class="form-group faq-search">
#         <form action="https://ccclib.org" autocomplete="off" method="get">
#           <label for="faqs_search_input">Search FAQs</label>
#           <div class="input-group">
#             <input name="post_type" type="hidden" value="bccms_faq" />
#             <input autocomplete="off" class="form-control text" id="faqs_search_input" name="s" testid="faqs_search_input" type="text" />
#             <span class="input-group-btn">
#               <button type="submit" class="btn btn-primary btn-flat">
#                 <i aria-hidden="true" class=" icon-search"></i>
#                 <span class="sr-only">Search</span>
#               </button>
#             </span>
#           </div>
# </form>      </div>
#
#         <ul class="form-group help_nav">
#               <li>
#                 <a href="https://ccclib.org/faq/library/" data-ga-category="header_help_nav_item" data-ga-label="Library Card FAQs">Library Card FAQs</a>
#               </li>
#               <li>
#                 <a href="https://ccclib.org/faq/borrowing/" data-ga-category="header_help_nav_item" data-ga-label="Borrowing FAQs">Borrowing FAQs</a>
#               </li>
#               <li>
#                 <a href="https://ccclib.org/faq/discover/" data-ga-category="header_help_nav_item" data-ga-label="Discover &amp; Go FAQs">Discover & Go FAQs</a>
#               </li>
#               <li>
#                 <a href="https://ccclib.org/faqs/" data-ga-category="header_help_nav_item" data-ga-label="All Library FAQs">All Library FAQs</a>
#               </li>
#               <li>
#                 <a href="https://help.bibliocommons.com/" data-ga-category="header_help_nav_item" data-ga-label="Catalog &amp; Account FAQs">Catalog & Account FAQs</a>
#               </li>
#
#         </ul>
#     </div>
#   </div>
# </div>
#
#           </div>
#           <!-- begin BCNAV -->
# <div data-js="bc_my_account_nav" class="bc_my_account_nav">
#   <!-- Template: t_biblionav_admin_nav -->
# <div class="admin_nav hidden"
#      data-js="biblionav_admin_nav"
#      testid="admin_nav">
#   <a href="#" aria-expanded="false" class="biblio_bar_link admin_nav_trigger dropdown-toggle hide_trigger_icon" data-js="admin_nav_trigger" data-toggle="dropdown" id="admin_nav_trigger" testid="admin_nav_trigger">
#     <svg aria-hidden="false" class="svg_icon " focusable="false" height="14" viewBox="0 0 30 32" width="14" xmlns="http://www.w3.org/2000/svg">
#   <title>Admin</title>
# <path d="M6.848 26.272q0-0.448-0.32-0.8t-0.8-0.32-0.8 0.32-0.352 0.8 0.352 0.8 0.8 0.352 0.8-0.352 0.32-0.8zM18.368 18.784l-12.192 12.192q-0.672 0.64-1.6 0.64t-1.632-0.64l-1.888-1.952q-0.672-0.64-0.672-1.6 0-0.928 0.672-1.632l12.16-12.16q0.704 1.76 2.048 3.104t3.104 2.048zM29.696 11.008q0 0.704-0.416 1.888-0.864 2.4-2.944 3.904t-4.608 1.472q-3.328 0-5.664-2.336t-2.336-5.664 2.336-5.632 5.664-2.368q1.024 0 2.144 0.32t1.92 0.832q0.288 0.192 0.288 0.48t-0.288 0.512l-5.216 3.008v4l3.456 1.92q0.064-0.064 1.408-0.864t2.4-1.44 1.28-0.64q0.256 0 0.416 0.16t0.16 0.448z"></path>
# </svg>
# <span aria-hidden="true" class="hidden-sm hidden-xs">Admin</span><span class="sr-only" data-js="sr-only-dropdown-toggle" data-text-collapsed="Admin, collapsed" data-text-expanded="Admin, expanded">Admin, collapsed</span><span aria-hidden="true" class="icon-arrow"></span></a>
#   <ul class="dropdown-menu admin_nav_menu"
#       data-js="admin_nav_menu"
#       aria-labelledby="admin_nav_trigger">
#   </ul>
# </div>
#
# <script id="t_biblionav_admin_nav" type="x-handlebars-template">
#   {{#if admin_nav.length}}
#     <li aria-hidden="true" class="dropdown-header">
#       Library
#     </li>
#
#     {{#each admin_nav}}
#       <li aria-hidden="true">
#         <a href="{{link}}" testid="biblionav_admin_{{locals.testid}}">{{title}}</a>
#       </li>
#     {{/each}}
#   {{/if}}
#
#   {{#if bcadmin_nav.length}}
#     <li aria-hidden="true" class="divider"></li>
#
#     <li aria-hidden="true" class="dropdown-header">
#       BC Admin
#     </li>
#
#     {{#each bcadmin_nav}}
#       <li aria-hidden="true">
#         <a href="{{link}}" testid="biblionav_admin_{{locals.testid}}">{{title}}</a>
#       </li>
#     {{/each}}
#   {{/if}}
# </script>
#
#
#   <div class="biblio_bar_my_account">
#     <a href="javascript:void(0);"
#        class="dropdown-toggle my_account_toggle biblio_bar_link hide_trigger_icon "
#        data-test-id="user_state_logged_out"
#        id="biblionav_account_trigger"
#        data-js="biblionav_account_trigger"
#        data-toggle="dropdown"
#        aria-haspopup="true"
#        aria-expanded="false">
#         <!-- Template: t_biblionav_account_trigger -->
#           <span data-test-id="biblio-bar-login">
#             Log In / My CCCLib
#           </span>
#     </a>
#
#     <ul class="dropdown-menu biblionav_my_account"
#         data-js="biblionav_my_account"
#         aria-labelledby="biblionav_account_trigger">
#
#       <!-- Template - t_biblionav_my_account_user_info -->
#       <li class="info" data-js="biblionav_my_account_user_info">
#         <a href="https://ccclib.bibliocommons.com/user/login" class="btn btn-transactional btn-block log_in_btn" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/user/login&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;Log In / Register&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" data-js="header_login_link" testid="biblionav_login">Log In / Register</a>
#       </li>
#
#
#         <li aria-hidden="true" role="presentation" class="divider"></li>
#
#
#           <li>
#             <a href="https://ccclib.bibliocommons.com/dashboard/user_dashboard" class=" " data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/dashboard/user_dashboard&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;My Library Dashboard&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_mylibrary">My Library Dashboard</a>
# </li>
#         <li aria-hidden="true" role="presentation" class="divider"></li>
#
#           <li class="dropdown-header">My Borrowing</li>
#
#           <li>
#             <a href="https://ccclib.bibliocommons.com/checkedout" class=" indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/checkedout&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;Checked Out&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_checkedout">Checked Out</a>
# </li>          <li>
#             <a href="https://ccclib.bibliocommons.com/holds" class=" indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/holds&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;On Hold&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_holds">On Hold</a>
# </li>          <li>
#             <a href="https://ccclib.bibliocommons.com/recentlyreturned" class="hidden indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/recentlyreturned&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;Borrowing History&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" data-js="borrowing_history_menu_item" testid="biblionav_borrowing_history">Borrowing History</a>
# </li>          <li>
#             <a href="https://ccclib.bibliocommons.com/fines" class=" indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/fines&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;Fees&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_fines">Fees</a>
# </li>          <li>
#             <a href="https://ccclib.bibliocommons.com/v2/interlibraryloans" class="hidden indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/v2/interlibraryloans&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;ILL Requests&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}">ILL Requests</a>
# </li>
#         <li aria-hidden="true" role="presentation" class="divider"></li>
#
#           <li class="dropdown-header">My Collections</li>
#
#           <li>
#             <a href="https://ccclib.bibliocommons.com/collection/show/my/library/for_later" class=" indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/collection/show/my/library/for_later&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;For Later Shelf&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_shelves_future">For Later Shelf</a>
# </li>          <li>
#             <a href="https://ccclib.bibliocommons.com/collection/show/my/library/completed" class=" indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/collection/show/my/library/completed&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;Completed Shelf&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_shelves_past">Completed Shelf</a>
# </li>          <li>
#             <a href="https://ccclib.bibliocommons.com/collection/show/my/library/in_progress" class=" indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/collection/show/my/library/in_progress&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;In Progress Shelf&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_shelves_present">In Progress Shelf</a>
# </li>          <li>
#             <a href="https://ccclib.bibliocommons.com/lists/show/mine" class=" indented" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/lists/show/mine&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;Lists&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_lists">Lists</a>
# </li>
#         <li aria-hidden="true" role="presentation" class="divider"></li>
#
#
#           <li>
#             <a href="https://ccclib.org/more-accounts/" class=" " data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_value&quot;:&quot;https://ccclib.org/more-accounts/&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;More Accounts&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}">More Accounts</a>
# </li>
#         <li aria-hidden="true" role="presentation" class="divider"></li>
#
#
#           <li>
#             <a href="https://ccclib.bibliocommons.com/user_profile/me" class=" " data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/user_profile/me&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;My Profile&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_myprofile">My Profile</a>
# </li>
#         <li aria-hidden="true" role="presentation" class="divider"></li>
#
#
#           <li>
#             <a href="https://ccclib.bibliocommons.com/account" class=" " data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_category_type&quot;:&quot;navigation&quot;,&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/account&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;My Settings&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_mysettings">My Settings</a>
# </li>
#       <!-- Template: t_biblionav_account_selector -->
#       <li data-js='biblionav_account_selector'></li>
#
#     </ul>
#   </div>
#
#
# </div>
# <!-- end BCNAV -->
#
# <script id="t_biblionav_divider" type="x-handlebars-template">
#   <li aria-hidden="true" role="presentation" class="divider" data-js="divider_{{divider_name}}"></li>
# </script>
#
# <script id="t_biblionav_account_trigger" type="x-handlebars-template">
#   {{#if logged_in}}
#     <div class="cp_user_avatar sm home_patron" testid="user_avatar_{{user_id}}">
#       {{#if user_avatar}}
#         <img src="{{user_avatar}}" class="img-circle" alt="">
#       {{else}}
#         <div class="img-circle initial"><span aria-hidden="true">{{user_initial}}</span></div>
#       {{/if}}
#     </div>
#     <span class="hidden-xs user_identity_name" aria-hidden= "true">{{user_name}}</span>
#     <span class="sr-only hidden-xs" data-js="sr-only-dropdown-toggle" data-text-collapsed="User {{user_name}}." data-text-expanded="User {{user_name}}.">User {{user_name}}.</span>
#     <span class="sr-only visible-xs" data-js="sr-only-dropdown-toggle" data-text-collapsed="For {{user_name}}. Double-tap to expand." data-text-expanded="Menu for {{user_name}} shows pop-up">For {{user_name}}. Double-tap to expand.</span>
#   {{else}}
#     <span aria-hidden= "true" class="my_account_label">Log In / My CCCLib</span>
#     <span class="sr-only" data-js="sr-only-dropdown-toggle" data-text-collapsed="User Log In / My CCCLib." data-text-expanded="User Log In / My CCCLib.">User Log In / My CCCLib.</span>
#   {{/if}}
#
#   <span class="icon-arrow" aria-hidden="true"></span>
# </script>
#
# <script id="t_biblionav_my_account_user_info" type="x-handlebars-template">
#   <li class="info" data-js="biblionav_my_account_user_info">
#     {{#if logged_in}}
#       <div class="pull-left">
#         <div class="my-account"><b>My Account</b></div>
#       </div>
#       <div class="pull-right notification-buttons">
#         <a href="https://ccclib.bibliocommons.com/user_profile/me/notification_feed" class="btn btn-default btn-flat" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/user_profile/me/notification_feed&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;{{unread_notifications}} notifications&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_notifications">
#             <i aria-hidden="true" class=" icon-bell"></i>
#             {{#if unread_notifications}}
#               <span class="badge" aria-hidden="true">{{unread_notifications}}</span>
#               <span class="sr-only">
#                 {{unread_notifications}} notifications
#               </span>
#             {{else}}
#               <span class="sr-only">Notifications</span>
#             {{/if}}
# </a>
#         <a href="https://ccclib.bibliocommons.com/account/personal_information" class="btn btn-default btn-flat" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/account/personal_information&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;My Settings&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_mysettings">
#           <i aria-hidden="true" class=" icon-cog"></i>
#           <span class="sr-only">My Settings</span>
# </a>      </div>
#       <a href="https://ccclib.bibliocommons.com/user/logout" class="btn btn-transactional btn-block log_out_btn" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/user/logout&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;Log Out&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" testid="biblionav_logout">Log Out</a>
#     {{else}}
#       <a href="https://ccclib.bibliocommons.com/user/login" class="btn btn-transactional btn-block log_in_btn" data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_value&quot;:&quot;https://ccclib.bibliocommons.com/user/login&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;Log In / Register&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}" data-js="header_login_link" testid="biblionav_login">Log In / Register</a>
#     {{/if}}
#   </li>
# </script>
#
# <script id="t_biblionav_account_selector" type="x-handlebars-template">
#   <ul>
#     <li aria-hidden="true" role="presentation" class="divider"></li>
#     <li aria-hidden="true" role="presentation" class="dropdown-header">
#       Switch Library Account
#     </li>
#     {{#each accounts}}
#       <li>
#         <a href="https://{{link}}"
#            class="indented"
#            data-analytics-payload="{&quot;method&quot;:&quot;trackNavigate&quot;,&quot;args&quot;:[{&quot;metadata&quot;:{&quot;metadata_value&quot;:&quot;https://{{link}}&quot;},&quot;ui&quot;:{&quot;ui_component_label&quot;:&quot;{{text}}&quot;,&quot;ui_component_type&quot;:&quot;link-text&quot;,&quot;ui_container_type&quot;:&quot;header-account-menu&quot;}}]}"
#            data-js="switch_linked_library"
#            data-host="{{link}}"
#            testid="biblionav_multiaccount_lib_{{text}}">
#           {{text}} <i aria-hidden="true" class=" icon-right"></i>
#         </a>
#       </li>
#     {{/each}}
#   </ul>
# </script>
#
#         </div>
#       </div>
#
#     </div>
#   </div>
# </div><!-- /.cp_header_biblio_bar -->
#
#
#       <div class="header_main">
#         <div class="client_and_search" data-test-id="header-desktop-search">
#   <div class="container">
#     <div class="pull-left cp_header_client_area">
#   <div class="pull-left logo">
#     <a href="https://ccclib.org"><picture><source media="(max-width: 991px)" sizes="200px" srcset="//cor-liv-cdn-static.bibliocommons.com/images/CA-CONTRACOSTA/logo.png?1707833757179" /><img alt="Contra Costa County Library" src="//cor-liv-cdn-static.bibliocommons.com/images/CA-CONTRACOSTA/logo.png?1707833757179" title="" /></picture></a>
#   </div>
#
#   <div class="pull-left visible-xs-block visible-sm-block xs_icon_triggers">
#     <a href="#" aria-label="Main navigation" data-ga-category="mobile_header_main_nav" data-ga-label="Mobile Main Nav" data-js="header_nav_xs_trigger" data-main-nav="true" data-target="header-main-nav" id="header_nav_xs_trigger" role="button"><i aria-hidden="true" class=" icon-menu"></i><span class="sr-only">Main navigation</span></a>
#
#   </div>
# </div>
#
#     <div class="visible-xs-block visible-sm-block xs_icon_triggers">
#       <a href="#" aria-label="Open search form" class="header_search_xs" data-icon-off="icon-cancel" data-icon-on="icon-search" data-js="header_search_xs_trigger" role="button"><i aria-hidden="true" class=" icon-search"></i><span class="sr-only">Open search form</span></a>
#     </div>
#
#     <div class="hidden-xs hidden-sm header_collapsible_search_wrapper">
#
#       <div class="header_search_wrapper header_search_wrapper_desktop header_search_catalogue" data-js="header_search_wrapper header_search_wrapper_desktop">
#         <div class="cp_header_search" id="header_search" data-js="header_search">
#           <div>
#               <div class="pull-left">
#                 <span class="connector" aria-hidden="true">Search the</span>
#                 <div class="bootstrap-select-wrapper" data-test-id="header-other-search-options"><select aria-label="Search alternatives" class=" selectpicker form-control" data-dropup-auto="false" data-js="header_search_target" data-style="btn-flat btn-default" name="searchOpt" testid="search_scope"><option value="catalogue" data-action="https://ccclib.bibliocommons.com/search" data-query-field="q">Catalog</option>
# <option value="website" data-action="https://ccclib.org" data-query-field="s">Website</option>
# <option value="faqs" data-action="https://ccclib.org" data-query-field="s">FAQs</option>
# <option value="events" data-action="https://ccclib.bibliocommons.com/events/search/q=__QUERY__" data-query-field="">Events</option>
# <option value="search_360" data-action="https://linkencore.iii.com/iii/encore/search/C__S__QUERY____Orightresult__U?lang=eng&amp;suite=def" data-query-field="">LINK+</option></select></div>
#
#               </div>
#
#             <form action="https://ccclib.bibliocommons.com/search" class="collapsible_search_form" data-js="header_search_form desktop_search_form" id="desktop_search_form" name="desktop_search_form">
#               <input data-js="header_search_origin" name="origin" type="hidden" value="user-query" />
#               <div class="pull-left">
#                     <div data-js="header_target_search_options" data-target="catalogue">
#                       <div class="form-group">
#   <span class="connector" aria-hidden="true">
#     by
#   </span>
#   <!-- begin SEARCH TYPE -->
# <div class="bootstrap-select-wrapper" data-test-id="header-search-type-dropdown"><select aria-label="Search type" class="form-control selectpicker form-control" data-dropup-auto="false" data-js="search_type" data-style="btn-flat btn-default" id="search_filter_id_1o2pqm4c3jlnc1uqi6e2no74jb" name="t" testid="search_filter"><option value="smart">Keyword</option>
# <option value="title">Title</option>
# <option value="author">Author</option>
# <option value="subject">Subject</option>
# <option value="tag">Tag</option>
# <option value="userlist">List</option>
# <option value="user">User</option></select></div>
#
# <input data-js="search_category" id="search_category_id_35rglnkvjnv3apob6ofq6c0em" name="search_category" testid="search_category" type="hidden" value="keyword" />
# <!-- end SEARCH TYPE-->
# </div>
#
#
#
#
# </div>                    <div class="hidden" data-js="header_target_search_options" data-target="website">
#                       <div class="form-group">
#   <span class="connector" aria-hidden="true">for</span>
#   <div class="bootstrap-select-wrapper"><select aria-label="Search within the website" class=" selectpicker form-control" data-dropup-auto="false" data-js="header_search_format" data-style="btn-flat btn-default" name="post_type" testid="cms_post_type"><option value="">All Content</option>
# <option value="bccms_faq">FAQs</option>
# <option value="bccms_news">News</option>
# <option value="post">Blog Posts</option></select></div>
# </div>
#
# </div>                    <div class="hidden" data-js="header_target_search_options" data-target="faqs">
#                       <input name="post_type" type="hidden" value="bccms_faq" />
#
# </div>              </div>
#
#               <!-- begin SEARCH INPUT -->
#
#   <div class="input-group header_search_box">
#
#     <label class="sr-only" for="search_box_id_5psbd6oresvjeapai84gtdog72">Enter search query</label>
#
#     <span class="main_search_input_wrapper" data-js="main_search_input_wrapper">
#       <input aria-activedescendant="" aria-autocomplete="both" aria-haspopup="listbox" aria-owns="header_auto_suggest_id_5s3g0gc871prau6fhcqa8p5dr0" autocomplete="off" class="form-control main_search_input text" data-js="main_search_input" id="search_box_id_5psbd6oresvjeapai84gtdog72" maxlength="1000" name="q" testid="main_search_input" type="search" />
#       <span class="header_search_filter_lock form-control-feedback" data-js="search_filter_locked" aria-hidden="true">
#         <svg aria-hidden="true" class="svg_icon " focusable="false" height="16" style="margin-top:10px;" viewBox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
#   <path d="M16 11.998V3.998H17V1.998H7V3.998H8V11.998L6 13.998V15.998H11.2V21.998H12.8V15.998H18V13.998L16 11.998Z" />
# </svg>
#       </span>
#
#       <button class="btn btn-link header_search_clear_button" data-js="header_search_clear_button" type="button">
#         <div class="sr-only">
#           Clear Text
#         </div>
#         <svg aria-hidden="true" class="svg_icon svg_close_icon" focusable="false" height="16" viewBox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
#   <rect width="2" height="16" x="6.964" y="-.036" fill="currentColor" transform="rotate(45 7.964 7.964)"/>
#   <rect width="2" height="16" x="6.964" y="-.036" fill="currentColor" transform="scale(-1 1) rotate(45 0 -11.263)"/>
# </svg>
# </button>
#         <div data-js="header_auto_suggest" class="cp_header_auto_suggest hidden">
#   <div data-js="auto_suggest_aria_messages" class="sr-only" role="alert" aria-live="polite" aria-atomic="false"></div>
#   <ul id="header_auto_suggest_id_5s3g0gc871prau6fhcqa8p5dr0" data-js="suggestion-menu" class="dropdown-menu" role="listbox"></ul>
#
#   <div class="hidden">
#     <svg aria-hidden="true" class="suggestion-skeleton-icon pulse" data-js="suggestion_skeleton_svg" focusable="false" height="14" preserveAspectRatio="xMinYMin meet" viewBox="0 0 10 10" width="14" xmlns="http://www.w3.org/2000/svg">
#   <rect fill="currentColor" width="2000" height="10"></rect>
# </svg>
#   </div>
# </div>
#
#
#     </span>
#
#     <span class="input-group-btn">
#       <button type="submit" class="btn btn-primary btn-flat">
#         <i aria-hidden="true" class=" icon-search"></i>
#         <span class="sr-only">Search</span>
#       </button>
#     </span>
#   </div>
#
# <!-- end SEARCH INPUT -->
#
# </form>          </div>
#
#           <div class="pull-right small adv_search">
#             <a href="https://ccclib.bibliocommons.com/user/saved_searches" class="hidden" data-ga-category="header_saved_searches" data-js="save_search_overlay" testid="link_savedsearches">Saved Searches</a>
#
#             <a href="https://ccclib.bibliocommons.com/search" test_id="link_advancedsearch">Advanced Search</a>
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div><!-- /.client_and_search -->
#
# <div class="clearfix header_search_wrapper search_wrapper_xs header_search_catalogue" data-js="header_search_wrapper header_search_wrapper_xs" data-test-id="header-mobile-search">
#   <div class="col-xs-12">
#     <div class="cp_header_search"  data-js="header_search">
#       <h2 data-js="header_search_title" class="header_search_title" tabindex="-1">
#         Search
#       </h2>
#
#         <div class="form-group">
#           <div class="bootstrap-select-wrapper" data-test-id="header-other-search-options"><select aria-label="Search alternatives" class=" selectpicker form-control" data-dropup-auto="false" data-js="header_search_target" data-style="btn-flat btn-default" name="searchOpt" testid="search_scope"><option value="catalogue" data-action="https://ccclib.bibliocommons.com/search" data-query-field="q">Catalog</option>
# <option value="website" data-action="https://ccclib.org" data-query-field="s">Website</option>
# <option value="faqs" data-action="https://ccclib.org" data-query-field="s">FAQs</option>
# <option value="events" data-action="https://ccclib.bibliocommons.com/events/search/q=__QUERY__" data-query-field="">Events</option>
# <option value="search_360" data-action="https://linkencore.iii.com/iii/encore/search/C__S__QUERY____Orightresult__U?lang=eng&amp;suite=def" data-query-field="">LINK+</option></select></div>
#
#         </div>
#
#       <form accept-charset="UTF-8" action="https://ccclib.bibliocommons.com/search" data-js="header_search_form mobile_search_form" id="mobile_search_form" method="get" name="mobile_search_form"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="&#x2713;" /></div>
#         <input data-js="header_search_origin" id="origin" name="origin" type="hidden" value="user-query" />
#             <div data-js="header_target_search_options" data-target="catalogue">
#               <div class="form-group">
#   <span class="connector" aria-hidden="true">
#     by
#   </span>
#   <!-- begin SEARCH TYPE -->
# <div class="bootstrap-select-wrapper" data-test-id="header-search-type-dropdown"><select aria-label="Search type" class="form-control selectpicker form-control" data-dropup-auto="false" data-js="search_type" data-style="btn-flat btn-default" id="search_filter_id_6s4aan8gnu3fnsf5fb01j9184o" name="t" testid="search_filter"><option value="smart">Keyword</option>
# <option value="title">Title</option>
# <option value="author">Author</option>
# <option value="subject">Subject</option>
# <option value="tag">Tag</option>
# <option value="userlist">List</option>
# <option value="user">User</option></select></div>
#
# ...
#  </li>
#  <li>
#  <a href="https://www.youtube.com/user/theccclib" class="social social-youtube" aria-label="Contra Costa County Library on Youtube">
#  <svg xmlns:xlink="http://www.w3.org/1999/xlink" aria-hidden="true" focusable="false" class="o-icon o-icon--footer-youtube" width="32" height="32" viewBox="-6 -9 32 32"><path fill-rule="evenodd" clip-rule="evenodd" d="M17.8139 0.417967C18.6744 0.647951 19.352 1.3256 19.582 2.18614C20 3.74582 20 7 20 7C20 7 20 10.2541 19.582 11.814C19.352 12.6744 18.6744 13.352 17.8139 13.5821C16.2542 14 10 14 10 14C10 14 3.74583 14 2.18612 13.5821C1.32564 13.352 0.647904 12.6744 0.417924 11.814C0 10.2541 0 7 0 7C0 7 0 3.74582 0.417924 2.18614C0.647904 1.3256 1.32564 0.647951 2.18612 0.417967C3.74583 0 10 0 10 0C10 0 16.2542 0 17.8139 0.417967ZM13.1818 7.00013L7.95454 9.95453V4.04546L13.1818 7.00013Z" fill="white"/></svg> </a>
#  </li>
#  </ul>
#  </div>
#  <div class="footer-all-menu-columns">
#  <div class="footer-1-container footer-menu-column"><h3 class="bccms-footer-heading">Services</h3><div class="menu-services-container"><ul id="menu-services" class="menu"><li id="menu-item-1124784" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1124784"><a href="https://ccclib.org/get-a-library-card-info/">Library Cards</a></li>
# <li id="menu-item-1811328" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1811328"><a href="https://ccclib.org/rooms/">Meeting/Study Rooms</a></li>
# <li id="menu-item-1124788" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1124788"><a href="https://ccclib.discoverandgo.net/" data-analytics='[{"event":"bc.outboundLinkClick","payload":{"gtmCategory":"v2-page-interactions","gtmAction":"v2-outbound-link-click","gtmLabel":"https:\/\/ccclib.discoverandgo.net\/","gtmValue":1,"gtmContentType":"","gtmContainerName":"","gtmContentCreator":"","gtmCreatorType":"","gtmCardTitle":""}}]'>Museum Passes</a></li>
# <li id="menu-item-1124790" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1124790"><a href="https://ccclib.org/computer/">Computers</a></li>
# <li id="menu-item-1124792" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1124792"><a href="https://ccclib.org/wireless/">Wi-Fi</a></li>
# <li id="menu-item-1838868" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1838868"><a href="https://ccclib.org/psc/">Adult Literacy</a></li>
# <li id="menu-item-2166058" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2166058"><a href="https://ccclib.org/government-information/">Federal Depository</a></li>
# <li id="menu-item-1838870" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1838870"><a href="https://ccclib.org/accessibility/">Accessibility</a></li>
# </ul></div></div><div class="footer-2-container footer-menu-column"><h3 class="bccms-footer-heading">About the Library</h3><div class="menu-about-the-library-container"><ul id="menu-about-the-library" class="menu"><li id="menu-item-1850618" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1850618"><a href="https://ccclib.org/about-us/">About Us</a></li>
# <li id="menu-item-3327546" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3327546"><a href="https://ccclib.org/holidays-and-closures/">Holidays and Closures</a></li>
# <li id="menu-item-1811326" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1811326"><a href="https://ccclib.org/newsroom/">Newsroom</a></li>
# <li id="menu-item-1186090" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1186090"><a href="https://ccclib.org/library-jobs/">Library Jobs</a></li>
# <li id="menu-item-1811322" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1811322"><a href="https://ccclib.org/strategic-plan/">Strategic Plan</a></li>
# <li id="menu-item-1811324" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1811324"><a href="https://ccclib.org/government-information/">Government Information</a></li>
# <li id="menu-item-3323022" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3323022"><a href="https://ccclib.org/commission/">Library Commission</a></li>
# <li id="menu-item-1722202" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1722202"><a href="https://ccclib.org/policies/">Library Policies</a></li>
# <li id="menu-item-3331496" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3331496"><a href="https://ccclib.org/sustainability/">Sustainability</a></li>
# </ul></div></div><div class="footer-3-container footer-menu-column"><h3 class="bccms-footer-heading">Help</h3><div class="menu-help-container"><ul id="menu-help" class="menu"><li id="menu-item-1124810" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1124810"><a href="https://ccclib.org/get-a-library-card-info/">Get a Library Card</a></li>
# <li id="menu-item-1124812" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1124812"><a href="https://help.bibliocommons.com/" data-analytics='[{"event":"bc.outboundLinkClick","payload":{"gtmCategory":"v2-page-interactions","gtmAction":"v2-outbound-link-click","gtmLabel":"https:\/\/help.bibliocommons.com\/","gtmValue":1,"gtmContentType":"","gtmContainerName":"","gtmContentCreator":"","gtmCreatorType":"","gtmCardTitle":""}}]'>Catalog and Account</a></li>
# <li id="menu-item-1124814" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1124814"><a href="https://ccclib.org/faqs/">FAQs</a></li>
# <li id="menu-item-1124816" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1124816"><a href="https://my.nicheacademy.com/ccclib" data-analytics='[{"event":"bc.outboundLinkClick","payload":{"gtmCategory":"v2-page-interactions","gtmAction":"v2-outbound-link-click","gtmLabel":"https:\/\/my.nicheacademy.com\/ccclib","gtmValue":1,"gtmContentType":"","gtmContainerName":"","gtmContentCreator":"","gtmCreatorType":"","gtmCardTitle":""}}]'>Tutorials</a></li>
# <li id="menu-item-3329046" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-3329046"><a href="https://ccclib.org/digital-navigators/">Digital Navigators</a></li>
# <li id="menu-item-2166056" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2166056"><a href="https://www.contracosta.ca.gov/" data-analytics='[{"event":"bc.outboundLinkClick","payload":{"gtmCategory":"v2-page-interactions","gtmAction":"v2-outbound-link-click","gtmLabel":"https:\/\/www.contracosta.ca.gov\/","gtmValue":1,"gtmContentType":"","gtmContainerName":"","gtmContentCreator":"","gtmCreatorType":"","gtmCardTitle":""}}]'>County Website</a></li>
# <li id="menu-item-3324646" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-3324646"><a href="https://www.contracosta.ca.gov/8570/ADA-Accessibility" data-analytics='[{"event":"bc.outboundLinkClick","payload":{"gtmCategory":"v2-page-interactions","gtmAction":"v2-outbound-link-click","gtmLabel":"https:\/\/www.contracosta.ca.gov\/8570\/ADA-Accessibility","gtmValue":1,"gtmContentType":"","gtmContainerName":"","gtmContentCreator":"","gtmCreatorType":"","gtmCardTitle":""}}]'>County Accessibility</a></li>
# </ul></div></div>
#  <div class="footer-menu-column footer-multi-row-column">
#  <div class="footer-4-container footer-menu-row"><h3 class="bccms-footer-heading">Support the Library</h3><div class="menu-support-the-library-container"><ul id="menu-support-the-library" class="menu"><li id="menu-item-1497118" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1497118"><a href="https://ccclib.org/volunteer/">Volunteer</a></li>
# <li id="menu-item-1423518" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1423518"><a href="https://ccclib.org/friends-and-foundations/">Friends and Foundations</a></li>
# <li id="menu-item-1811320" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1811320"><a href="https://ccclib.org/donate/">Donate to the Library</a></li>
# </ul></div></div><div class="footer-5-container footer-menu-row"></div> </div>
#  <div class="footer-menu-column">
#  <div class="footer-contact-info large-footer">
#  <h3 class="a11y-visually-hidden">Contact the Library</h3>
#  <div>
#  <div>Contra Costa County Library</div>
#  <div></div>
#  <div></div>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <a href="https://ccclib.org/contact-us/"
#  class="feedback-btn"><span>Contact Us</span></a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="footer-contact-info small-footer">
#  <div class="small-footer-content">
#  <!-- Footer to be shown on small screen sizes. -->
#  <h3 class="a11y-visually-hidden">Contact the Library</h3>
#  <div>
#  <div>Contra Costa County Library</div>
#  <div></div>
#  <div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="clear"></div>
#  <div class="footer-bottom clearfix">
#  <a href="https://ccclib.org/contact-us/"
#  class="feedback-btn-small">Contact Us</a>
#  <div class="clear"></div>
#  <div class="support-lib-link">
#  </div>
#  <div class="footer-col-2">
#  <div id="green-links-wrapper">
#  </div>
#  <div class="clear"></div>
#  <div class="footer-bottom-copyright">
#  <a href="https://ccclib.bibliocommons.com/info/terms" target="_blank" rel="noopener noreferrer">
#  Terms of Use<span class="a11y-visually-hidden">, opens a new window</span><!--
#  --></a>
#  <a href="https://ccclib.bibliocommons.com/info/privacy" target="_blank" rel="noopener noreferrer">
#  Privacy Statement<span class="a11y-visually-hidden">, opens a new window</span><!--
#  --></a>
#  <a href="https://ccclib.bibliocommons.com/info/accessibility/" target="_blank" rel="noopener noreferrer">
#  Accessibility Statement<span class="a11y-visually-hidden">, opens a new window</span><!--
#  --></a>
#  <span class="copyright-statement">
#  © 2024 Contra Costa County Library </span>
#  </div>
#  </div>
#  </div>
# </footer>
# </div>
#   </div>
#
# </div>
# </div><div class="container"><div class="cp-version-message"><p class="powered-by"><span>Powered by BiblioCommons.</span></p><p class="product-version">NERF:<!-- -->nerf17 Version 9.20.2@c0175bc Last updated 2024/02/08 12:56 Built 2024/02/08 16:06</p></div></div></div><button class="cp-btn btn btn-secondary cp-back-to-top"><svg focusable="false" aria-hidden="true" class="icon-svg-arrow-medium-up " width="16" height="16" viewBox="0 0 18 16"><path fill="#fff" d="M0 10.5l2 2 6-6 6 6 2-2-8-8-8 8z"></path></svg> <!-- -->To top</button></div></div></div>
# <script type="application/json" data-iso-key="_0">{"app":{"coreCssFingerprint":"1707415540547","coreAssets":{"cdnHost":"https://cor-liv-cdn-static.bibliocommons.com","cssPath":"/dynamic_stylesheet","defaultStylesheet":"library_branding.css"},"airbrakeConfig":{"enabled":true,"env":"live","projectId":"116837","projectKey":"ac785af5440658f1a66a40a30b07cc9e"},"enableWebpackHMR":false,"apiGatewayURL":"https://gateway.bibliocommons.com/v2","authRequired":false,"browser":"","accountRequired":false,"localBranch":null,"globalPaymentsBaseUrl":"https://pay.realexpayments.com","featureOverrides":{},"mobileAppPlatform":null,"datadogConfig":{},"currentURL":"/v2/locations","basePath":"/v2","enableReduxDevTools":false,"appVersion":"nerf17 Version 9.20.2@c0175bc Last updated 2024/02/08 12:56 Built 2024/02/08 16:06","coreVersion":"9.20.2","mobileAppVersion":null,"baseURL":"https://ccclib.bibliocommons.com","libraryDomain":"ccclib","mobileApp":false},"entities":{"mediaSummaries":{},"eventLanguages":{},"listItems":{},"cards":{},"authorSuggestions":{},"interlibraryLoans":{},"promos":{},"bibItems":{},"suggestForPurchase":{},"accounts":{},"holdableItems":{},"borrowingHistory":{},"shelves":{},"users":{},"eventPrograms":{},"featuredContent":{},"places":{},"messages":{},"sites":{},"checkouts":{},"holdings":{},"ugc":{},"eventSeries":{},"catalogBibs":{},"excerpts":{},"holds":{},"eventAudiences":{},"lists":{},"ignoredUsers":{},"specialHours":{"655549e6e7f74a2a0042f148":{"id":"655549e6e7f74a2a0042f148","name":"All libraries closed - Thanksgiving Day","startDate":"2024-11-28","endDate":"2024-11-28","openTime":null,"closeTime":null,"allLocations":true,"locationIds":[]},"655548ba209f48310029831a":{"id":"655548ba209f48310029831a","name":"All libraries closed - Independence Day","startDate":"2024-07-04","endDate":"2024-07-04","allLocations":true,"locationIds":[]},"65554967b6d98938007f95ce":{"id":"65554967b6d98938007f95ce","name":"All libraries closed - Veterans Day","startDate":"2024-11-11","endDate":"2024-11-11","allLocations":true,"locationIds":[]},"6573637861803d36007078d1":{"id":"6573637861803d36007078d1","name":"All libraries close at 5:00 p.m. - New Year's Eve","startDate":"2024-12-31","endDate":"2024-12-31","openTime":null,"closeTime":"T17:00","allLocations":true,"locationIds":[]},"65554a31a5dbe03f0072075a":{"id":"65554a31a5dbe03f0072075a","name":"All libraries closed - Christmas Day","startDate":"2024-12-25","endDate":"2024-12-25","allLocations":true,"locationIds":[]},"65554991a5dbe03f00720750":{"id":"65554991a5dbe03f00720750","name":"All libraries close at 6:00 pm - (Day before Thanksgiving)","startDate":"2024-11-27","endDate":"2024-11-27","openTime":null,"closeTime":"T18:00","allLocations":true,"locationIds":[]},"655548dbe7f74a2a0042f134":{"id":"655548dbe7f74a2a0042f134","name":"All libraries closed - Labor Day","startDate":"2024-09-02","endDate":"2024-09-02","allLocations":true,"locationIds":[]},"6555487fb6d98938007f9587":{"id":"6555487fb6d98938007f9587","name":"All libraries closed - Memorial Day","startDate":"2024-05-27","endDate":"2024-05-27","allLocations":true,"locationIds":[]},"65554a0fe7f74a2a0042f149":{"id":"65554a0fe7f74a2a0042f149","name":"All libraries closed - Christmas Eve","startDate":"2024-12-24","endDate":"2024-12-24","allLocations":true,"locationIds":[]},"6573633feb28943d007b1ffa":{"id":"6573633feb28943d007b1ffa","name":"All libraries closed - All Staff Training Day","startDate":"2024-03-20","endDate":"2024-03-20","allLocations":true,"locationIds":[]},"65554892e7f74a2a0042f10d":{"id":"65554892e7f74a2a0042f10d","name":"All libraries closed - Juneteenth","startDate":"2024-06-19","endDate":"2024-06-19","allLocations":true,"locationIds":[]},"65554862209f4831002982e4":{"id":"65554862209f4831002982e4","name":"All libraries closed - Presidents' Day","startDate":"2024-02-19","endDate":"2024-02-19","allLocations":true,"locationIds":[]}},"subscriptions":{},"facilityTypes":{"5cf174644b4ce2491770d47e":{"label":"Assistive Technology Computer","id ...
#     <script src="https://cdn-nerf.bibliocommons.com/globals-87fdde4b42.js"></script>
#     <script src="//cor-cdn-static.bibliocommons.com/assets/responsive_external_header-11cbf52e01b3bde58bc8f7d20e5c4ef0.js" type="text/javascript"></script>
#
#     <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[15,56,46]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["EnhancedStyles","app-components-locations-LocationsPage-LocationsPage"]}</script>
# <script async data-chunk="main" src="https://cdn-nerf.bibliocommons.com/app.main-7658bc69f3ad54d05cb2.js"></script>
# <script async data-chunk="EnhancedStyles" src="https://cdn-nerf.bibliocommons.com/app.EnhancedStyles-ae051d93f6f43cdeff9b.js"></script>
# <script async data-chunk="app-components-locations-LocationsPage-LocationsPage" src="https://cdn-nerf.bibliocommons.com/app.56-18dcd03437d701fca447.js"></script>
# <script async data-chunk="app-components-locations-LocationsPage-LocationsPage" src="https://cdn-nerf.bibliocommons.com/app.app-components-locations-LocationsPage-LocationsPage-3b855117ad51f54c6d69.js"></script>
#   </body>
# </html>

# %%
bs = BeautifulSoup(location_html_content, 'html.parser')

# %%
locations_data = []

for item in bs.select('article.cp-location-item-info'):
    city = item.select_one('h2 > a').text
    link = item.select_one('h2 > a')['href']
    lid = int(link.split("/")[-1])
    contacts = item.select_one('div.contacts')
    phone = contacts.select_one('a').get_text() if contacts else None
    address1 = item.select_one('div.cp-location-address').select('div')[0].text
    address2 = item.select_one('div.cp-location-address').select('div')[1].text
    address = address1 + ' ' + address2
    location_json_data = {
        'id': lid,
        'city': city,
        'website': link,
        'phone_number': phone,
        'address': address
    }
    print(location_json_data)
    locations_data.append(location_json_data)
# Out:
# {'id': 1, 'city': 'Antioch', 'website': 'https://ccclib.org/locations/1', 'phone_number': '(925) 757-9224', 'address': '501 W. 18th Street Antioch, CA 94509'}
# {'id': 2, 'city': 'Bay Point', 'website': 'https://ccclib.org/locations/2', 'phone_number': '(925) 458-9597', 'address': '205 Pacifica Avenue Bay Point, CA 94565'}
# {'id': 4, 'city': 'Brentwood', 'website': 'https://ccclib.org/locations/4', 'phone_number': '(925) 516-5290', 'address': '104 Oak Street Brentwood, California 94513'}
# {'id': 6, 'city': 'Clayton', 'website': 'https://ccclib.org/locations/6', 'phone_number': '(925) 673-0659', 'address': '6125 Clayton Road Clayton, CA 94517'}
# {'id': 7, 'city': 'Concord', 'website': 'https://ccclib.org/locations/7', 'phone_number': '(925) 646-5455', 'address': '2900 Salvio Street Concord, CA 94519'}
# {'id': 8, 'city': 'Crockett', 'website': 'https://ccclib.org/locations/8', 'phone_number': '(510) 787-2345', 'address': '991 Loring Avenue Crockett, CA 94525'}
# {'id': 9, 'city': 'Danville', 'website': 'https://ccclib.org/locations/9', 'phone_number': '(925) 314-3750', 'address': '400 Front Street Danville, CA 94526'}
# {'id': 60, 'city': 'Dougherty Station', 'website': 'https://ccclib.org/locations/60', 'phone_number': '(925) 973-3380', 'address': '17017 Bollinger Canyon Road San Ramon, CA 94582'}
# {'id': 11, 'city': 'El Cerrito', 'website': 'https://ccclib.org/locations/11', 'phone_number': '(510) 526-7512', 'address': '6510 Stockton Avenue El Cerrito, CA 94530'}
# {'id': 12, 'city': 'El Sobrante', 'website': 'https://ccclib.org/locations/12', 'phone_number': '(510) 374-3991', 'address': '4191 Appian Way El Sobrante, CA 94803'}
# {'id': 55, 'city': 'Hercules', 'website': 'https://ccclib.org/locations/55', 'phone_number': '(510) 245-2420', 'address': '109 Civic Drive Hercules, CA 94547'}
# {'id': 77, 'city': 'Juvenile Hall - Staff Use Only', 'website': 'https://ccclib.org/locations/77', 'phone_number': None, 'address': 'Closed to the general public Martinez, CA 94553'}
# {'id': 13, 'city': 'Kensington', 'website': 'https://ccclib.org/locations/13', 'phone_number': '(510) 524-3043', 'address': '61 Arlington Avenue Kensington, CA 94707'}
# {'id': 14, 'city': 'Lafayette', 'website': 'https://ccclib.org/locations/14', 'phone_number': '(925) 385-2280', 'address': '3491 Mt. Diablo Boulevard Lafayette, CA 94549'}
# {'id': 16, 'city': 'Martinez', 'website': 'https://ccclib.org/locations/16', 'phone_number': '(925) 646-9900', 'address': '740 Court Street Martinez, CA 94553'}
# {'id': 15, 'city': 'Moraga', 'website': 'https://ccclib.org/locations/15', 'phone_number': '(925) 376-6852', 'address': "1500 St. Mary's Road Moraga, CA 94556"}
# {'id': 17, 'city': 'Oakley', 'website': 'https://ccclib.org/locations/17', 'phone_number': '(925) 625-2400', 'address': '1050 Neroly Road Oakley, CA 94561'}
# {'id': 19, 'city': 'Orinda', 'website': 'https://ccclib.org/locations/19', 'phone_number': '(925) 254-2184', 'address': '26 Orinda Way Orinda, CA 94563'}
# {'id': 20, 'city': 'Pinole', 'website': 'https://ccclib.org/locations/20', 'phone_number': '(510) 758-2741', 'address': '2935 Pinole Valley Road Pinole, CA 94564'}
# {'id': 21, 'city': 'Pittsburg', 'website': 'https://ccclib.org/locations/21', 'phone_number': '(925) 427-8390', 'address': '80 Power Avenue Pittsburg, CA 94565'}
# {'id': 43, 'city': 'Pleasant Hill', 'website': 'https://ccclib.org/locations/43', 'phone_number': '(925) 349-0883', 'address': '2 Monticello Avenue Pleasant Hill, CA 94523'}
# {'id': 94, 'city': 'Prewett', 'website': 'https://ccclib.org/locations/94', 'phone_number': '(925) 776-3060', 'address': '4703 Lone Tree Way Antioch, CA 94531'}
# {'id': 23, 'city': 'Rodeo', 'website': 'https://ccclib.org/locations/23', 'phone_number': '(510) 799-2606', 'address': '220 Pacific Avenue Rodeo, CA 94572'}
# {'id': 24, 'city': 'San Pablo', 'website': 'https://ccclib.org/locations/24', 'phone_number': '(510) 374-3998', 'address': '13751 San Pablo Avenue San Pablo, CA 94806'}
# {'id': 25, 'city': 'San Ramon', 'website': 'https://ccclib.org/locations/25', 'phone_number': '(925) 973-2850', 'address': '100 Montgomery Street San Ramon, CA 94583'}
# {'id': 26, 'city': 'Walnut Creek', 'website': 'https://ccclib.org/locations/26', 'phone_number': '(925) 977-3340', 'address': '1644  N. Broadway Walnut Creek, CA 94596'}
# {'id': 27, 'city': 'Ygnacio Valley', 'website': 'https://ccclib.org/locations/27', 'phone_number': '(925) 938-1481', 'address': '2661 Oak Grove Road Walnut Creek, CA 94598'}

# %%
locations = pd.DataFrame(locations_data).sort_values(by='id')
show_table(locations)
# Out:
#    id | city                           | website                         | phone_number   | address
# ------+--------------------------------+---------------------------------+----------------+-------------------------------------------------
#     1 | Antioch                        | https://ccclib.org/locations/1  | (925) 757-9224 | 501 W. 18th Street Antioch, CA 94509
#     2 | Bay Point                      | https://ccclib.org/locations/2  | (925) 458-9597 | 205 Pacifica Avenue Bay Point, CA 94565
#     4 | Brentwood                      | https://ccclib.org/locations/4  | (925) 516-5290 | 104 Oak Street Brentwood, California 94513
#     6 | Clayton                        | https://ccclib.org/locations/6  | (925) 673-0659 | 6125 Clayton Road Clayton, CA 94517
#     7 | Concord                        | https://ccclib.org/locations/7  | (925) 646-5455 | 2900 Salvio Street Concord, CA 94519
#     8 | Crockett                       | https://ccclib.org/locations/8  | (510) 787-2345 | 991 Loring Avenue Crockett, CA 94525
#     9 | Danville                       | https://ccclib.org/locations/9  | (925) 314-3750 | 400 Front Street Danville, CA 94526
#    11 | El Cerrito                     | https://ccclib.org/locations/11 | (510) 526-7512 | 6510 Stockton Avenue El Cerrito, CA 94530
#    12 | El Sobrante                    | https://ccclib.org/locations/12 | (510) 374-3991 | 4191 Appian Way El Sobrante, CA 94803
#    13 | Kensington                     | https://ccclib.org/locations/13 | (510) 524-3043 | 61 Arlington Avenue Kensington, CA 94707
#    14 | Lafayette                      | https://ccclib.org/locations/14 | (925) 385-2280 | 3491 Mt. Diablo Boulevard Lafayette, CA 94549
#    15 | Moraga                         | https://ccclib.org/locations/15 | (925) 376-6852 | 1500 St. Mary's Road Moraga, CA 94556
#    16 | Martinez                       | https://ccclib.org/locations/16 | (925) 646-9900 | 740 Court Street Martinez, CA 94553
#    17 | Oakley                         | https://ccclib.org/locations/17 | (925) 625-2400 | 1050 Neroly Road Oakley, CA 94561
#    19 | Orinda                         | https://ccclib.org/locations/19 | (925) 254-2184 | 26 Orinda Way Orinda, CA 94563
#    20 | Pinole                         | https://ccclib.org/locations/20 | (510) 758-2741 | 2935 Pinole Valley Road Pinole, CA 94564
#    21 | Pittsburg                      | https://ccclib.org/locations/21 | (925) 427-8390 | 80 Power Avenue Pittsburg, CA 94565
#    23 | Rodeo                          | https://ccclib.org/locations/23 | (510) 799-2606 | 220 Pacific Avenue Rodeo, CA 94572
#    24 | San Pablo                      | https://ccclib.org/locations/24 | (510) 374-3998 | 13751 San Pablo Avenue San Pablo, CA 94806
#    25 | San Ramon                      | https://ccclib.org/locations/25 | (925) 973-2850 | 100 Montgomery Street San Ramon, CA 94583
#    26 | Walnut Creek                   | https://ccclib.org/locations/26 | (925) 977-3340 | 1644  N. Broadway Walnut Creek, CA 94596
#    27 | Ygnacio Valley                 | https://ccclib.org/locations/27 | (925) 938-1481 | 2661 Oak Grove Road Walnut Creek, CA 94598
#    43 | Pleasant Hill                  | https://ccclib.org/locations/43 | (925) 349-0883 | 2 Monticello Avenue Pleasant Hill, CA 94523
#    55 | Hercules                       | https://ccclib.org/locations/55 | (510) 245-2420 | 109 Civic Drive Hercules, CA 94547
#    60 | Dougherty Station              | https://ccclib.org/locations/60 | (925) 973-3380 | 17017 Bollinger Canyon Road San Ramon, CA 94582
#    77 | Juvenile Hall - Staff Use Only | https://ccclib.org/locations/77 |                | Closed to the general public Martinez, CA 94553
#    94 | Prewett                        | https://ccclib.org/locations/94 | (925) 776-3060 | 4703 Lone Tree Way Antioch, CA 94531

# %%
show_table(duckdb.query("SELECT * FROM locations ORDER BY 1").df())
# Out:
#    id | city                           | website                         | phone_number   | address
# ------+--------------------------------+---------------------------------+----------------+-------------------------------------------------
#     1 | Antioch                        | https://ccclib.org/locations/1  | (925) 757-9224 | 501 W. 18th Street Antioch, CA 94509
#     2 | Bay Point                      | https://ccclib.org/locations/2  | (925) 458-9597 | 205 Pacifica Avenue Bay Point, CA 94565
#     4 | Brentwood                      | https://ccclib.org/locations/4  | (925) 516-5290 | 104 Oak Street Brentwood, California 94513
#     6 | Clayton                        | https://ccclib.org/locations/6  | (925) 673-0659 | 6125 Clayton Road Clayton, CA 94517
#     7 | Concord                        | https://ccclib.org/locations/7  | (925) 646-5455 | 2900 Salvio Street Concord, CA 94519
#     8 | Crockett                       | https://ccclib.org/locations/8  | (510) 787-2345 | 991 Loring Avenue Crockett, CA 94525
#     9 | Danville                       | https://ccclib.org/locations/9  | (925) 314-3750 | 400 Front Street Danville, CA 94526
#    11 | El Cerrito                     | https://ccclib.org/locations/11 | (510) 526-7512 | 6510 Stockton Avenue El Cerrito, CA 94530
#    12 | El Sobrante                    | https://ccclib.org/locations/12 | (510) 374-3991 | 4191 Appian Way El Sobrante, CA 94803
#    13 | Kensington                     | https://ccclib.org/locations/13 | (510) 524-3043 | 61 Arlington Avenue Kensington, CA 94707
#    14 | Lafayette                      | https://ccclib.org/locations/14 | (925) 385-2280 | 3491 Mt. Diablo Boulevard Lafayette, CA 94549
#    15 | Moraga                         | https://ccclib.org/locations/15 | (925) 376-6852 | 1500 St. Mary's Road Moraga, CA 94556
#    16 | Martinez                       | https://ccclib.org/locations/16 | (925) 646-9900 | 740 Court Street Martinez, CA 94553
#    17 | Oakley                         | https://ccclib.org/locations/17 | (925) 625-2400 | 1050 Neroly Road Oakley, CA 94561
#    19 | Orinda                         | https://ccclib.org/locations/19 | (925) 254-2184 | 26 Orinda Way Orinda, CA 94563
#    20 | Pinole                         | https://ccclib.org/locations/20 | (510) 758-2741 | 2935 Pinole Valley Road Pinole, CA 94564
#    21 | Pittsburg                      | https://ccclib.org/locations/21 | (925) 427-8390 | 80 Power Avenue Pittsburg, CA 94565
#    23 | Rodeo                          | https://ccclib.org/locations/23 | (510) 799-2606 | 220 Pacific Avenue Rodeo, CA 94572
#    24 | San Pablo                      | https://ccclib.org/locations/24 | (510) 374-3998 | 13751 San Pablo Avenue San Pablo, CA 94806
#    25 | San Ramon                      | https://ccclib.org/locations/25 | (925) 973-2850 | 100 Montgomery Street San Ramon, CA 94583
#    26 | Walnut Creek                   | https://ccclib.org/locations/26 | (925) 977-3340 | 1644  N. Broadway Walnut Creek, CA 94596
#    27 | Ygnacio Valley                 | https://ccclib.org/locations/27 | (925) 938-1481 | 2661 Oak Grove Road Walnut Creek, CA 94598
#    43 | Pleasant Hill                  | https://ccclib.org/locations/43 | (925) 349-0883 | 2 Monticello Avenue Pleasant Hill, CA 94523
#    55 | Hercules                       | https://ccclib.org/locations/55 | (510) 245-2420 | 109 Civic Drive Hercules, CA 94547
#    60 | Dougherty Station              | https://ccclib.org/locations/60 | (925) 973-3380 | 17017 Bollinger Canyon Road San Ramon, CA 94582
#    77 | Juvenile Hall - Staff Use Only | https://ccclib.org/locations/77 |                | Closed to the general public Martinez, CA 94553
#    94 | Prewett                        | https://ccclib.org/locations/94 | (925) 776-3060 | 4703 Lone Tree Way Antioch, CA 94531
